# %% [markdown]
# # Convert from json to table

# %%
import json
import os
import pandas as pd

# %%
converter = NHLConverter('ift6758/data/raw/NHL/20162017.json')

converter.pull_json()
# Out:
# 1317

# %%
clean = converter.convert_season()
# Out:
# 80399

# %%
clean.iloc[:10, :]
# Out:
#          game starttime          game endtime  gameId  offense_team_id  \
# 0  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       0               10
# 1  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       1                9
# 2  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       2                9
# 3  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       3                9
# 4  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       4               10
# 5  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       5               10
# 6  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       6               10
# 7  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       7               10
# 8  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       8                9
# 9  2016-10-12T23:00:00Z  2016-10-13T01:56:40Z       9                9
#
#      offense_team_name offense_team_tricode  goal  x_coords  y_coords  \
# 0  Toronto Maple Leafs                  TOR     0     -77.0       5.0
# 1      Ottawa Senators                  OTT     0      86.0      13.0
# 2      Ottawa Senators                  OTT     0      23.0     -38.0
# 3      Ottawa Senators                  OTT     0      33.0     -15.0
# 4  Toronto Maple Leafs                  TOR     0     -34.0      28.0
# 5  Toronto Maple Leafs                  TOR     0     -33.0     -17.0
# 6  Toronto Maple Leafs                  TOR     1     -70.0       1.0
# 7  Toronto Maple Leafs                  TOR     0     -45.0     -36.0
# 8      Ottawa Senators                  OTT     0      33.0     -18.0
# 9      Ottawa Senators                  OTT     0      34.0      20.0
#
#    goalie_id        goalie_name  shooter_id     shooter_name   shot type  \
# 0    8467950     Craig Anderson     8478483  Mitchell Marner  Wrist Shot
# 1    8475883  Frederik Andersen     8467967      Chris Kelly  Wrist Shot
# 2    8475883  Frederik Andersen     8476879        Cody Ceci  Wrist Shot
# 3    8475883  Frederik Andersen     8474578    Erik Karlsson   Slap Shot
# 4    8467950     Craig Anderson     8475716  Martin Marincin  Wrist Shot
# 5    8467950     Craig Anderson     8478483  Mitchell Marner  Wrist Shot
# 6    8467950     Craig Anderson     8479318  Auston Matthews  Wrist Shot
# 7    8467950     Craig Anderson     8474709      Matt Martin  Wrist Shot
# 8    8475883  Frederik Andersen     8474578    Erik Karlsson   Slap Shot
# 9    8475883  Frederik Andersen     8474578    Erik Karlsson  Wrist Shot
#
#   empty net  strength_shorthand  strength_even  strength_powerplay
# 0     False                 NaN            NaN                 NaN
# 1     False                 NaN            NaN                 NaN
# 2     False                 NaN            NaN                 NaN
# 3     False                 NaN            NaN                 NaN
# 4     False                 NaN            NaN                 NaN
# 5     False                 NaN            NaN                 NaN
# 6     False                 0.0            1.0                 0.0
# 7     False                 NaN            NaN                 NaN
# 8     False                 NaN            NaN                 NaN
# 9     False                 NaN            NaN                 NaN
