# %%
# if someone knows why I need this and how I can remove it, feel free to remove it
import sys
sys.path.append('..')

from ift6758.data.cleaner import NHLCleaner
from ift6758.visualizations.simple import NHLSimpleVisualization

# %%
# load 2016-2017
df = NHLCleaner.format_season("../data/20162017.json")

# %%
# instantiate visualization object for 2016-2017
sv = NHLSimpleVisualization(df)

# %%
# show plot for 5.1
sv.shot_types(title="Shots taken and goals scored by type (2016-2017)")

# %%
# show plot for 5.3
sv.shot_type_and_distance(title="Proportion of successful shots by type and distance (2016-2017)", bins=range(0, 101, 10))
# Out:
# /home/valmi/ac/mila/datasci/tp/IFT6758/notebooks/../ift6758/visualizations/simple.py:220: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_df.columns)
# /home/valmi/ac/mila/datasci/tp/IFT6758/notebooks/../ift6758/visualizations/simple.py:221: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(new_df.index)

# %%
# load data and show plots for 5.2
for (s, e) in [("2018", "2019"), ("2019", "2020"), ("2020", "2021")]:
    df = NHLCleaner.format_season(f"../data/{s}{e}.json")
    sv = NHLSimpleVisualization(df)
    
    # old style:
    #sv.shot_distance(title=f"Proportion of successful shots by distance ({s}-{e})")
    
    # human-readable style:
    sv.shot_distance(title=f"Proportion of successful shots by distance ({s}-{e})", bins=range(0, 101, 10))
